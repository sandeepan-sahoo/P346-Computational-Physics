# %%
import matplotlib.pyplot as plt
import math
from MyLibrary import *
def f3(x,y,z):
    return 1-x-z 
def f2(x,z):
    return z
def f8(x):
    return rk4s(f2,f3,0,x,2,0,0.05)
print("The value of y at x=5")
print(rk4s(f2,f3,0,5,2,0,0.05))
xval = []
yval = []
#taking a step size of 0.05, there are 10/0.05= 200 iterations
for i in range(200):
    xval.append(-5+ i*0.05)
    yval.append(f8(xval[i]))
plt.plot(xval,yval)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y v x")
# Out:
# The value of y at x=5
# 1.818500000000001
# Text(0.5, 1.0, 'y v x')
